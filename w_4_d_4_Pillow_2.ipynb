# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
im1=Image.open("jp.jpg")
im2=Image.open("tb.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-29fc84f55f76> in <module>()
# ----> 1 im1=Image.open("jp.jpg")
#       2 im2=Image.open("tb.png")
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jp.jpg'

# %%
im1.show()

# %%
plt.imshow(im1)

# %%
plt.imshow(im2)

# %%
print(im1.size,im1.format,im1.mode)

# %%
im2.save("new_im2.jpg")

# %%
left=50
top=120
right=250
bottom=230
crop_image=im1.crop((left,top,right,bottom))
plt.imshow(crop_image)
crop_image.save("crop_img.jpg")

# %%
cr_img=Image.open("crop_img.jpg")
plt.imshow("crop_image.jpg")
